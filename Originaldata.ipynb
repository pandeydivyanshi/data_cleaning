# %%
import pandas as pd 
df = pd.read_csv(r"c:\Users\divya\Downloads\winequality-red-dirty.csv")
print(df.to_string())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  sulphates    alcohol  quality
# 0               7.4             0.700        0.000            1.90      0.076                 11.0                  34.0  0.99780  3.510       0.56   9.400000        5
# 1               7.8             0.880        0.000            2.60      0.098                 25.0                  67.0  0.99680  3.200       0.68   9.800000        5
# 2               7.8             0.760        0.040            2.30      0.092                 15.0                  54.0  0.99700  3.260       0.65   9.800000        5
# 3              11.2             0.280        0.560            1.90      0.075                 17.0                  60.0  0.99800  3.160       0.58   9.800000        6
# ...
