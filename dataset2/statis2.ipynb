# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
x=pd.read_csv(r'C:\Users\divya\OneDrive\Desktop\data_cleaning\data_cleaning\dataset2\cleaned_file2.csv')

# %% [markdown]
# #descriptive statisctics

# %%
print("🔹 Descriptive Statistics:")
print(x.describe().round(3))
# Out:
# 🔹 Descriptive Statistics:
#        Unnamed: 0       ID      Age  Income in Rs.    Score  Purchases
# count     200.000  200.000  200.000        200.000  200.000    200.000
# mean       99.500  100.500   38.725      52691.970   54.960      4.990
# std        57.879   57.879   12.573      14729.709   73.828      2.196
# min         0.000    1.000   18.000      20075.000    1.000      1.000
# 25%        49.750   50.750   28.000      42266.750   20.750      3.000
# 50%        99.500  100.500   40.000      52057.500   52.000      5.000
# 75%       149.250  150.250   49.250      63876.250   79.000      7.000
# max       199.000  200.000   59.000      91016.000  999.000     11.000

# %% [markdown]
# #for saftey check empty cells

# %%
print("\n🔹 Missing Values:")
print(x.isnull().sum())
# Out:
# 🔹 Missing Values:
# Unnamed: 0       0
# ID               0
# Age              0
# Income in Rs.    0
# Score            0
# Purchases        0
# dtype: int64

# %% [markdown]
# #SKEWNESS AND KURTOSIS

# %%
print("\n🔹 Skewness:")
print(x.skew(numeric_only=True).round(3))

print("\n🔹 Kurtosis:")
print(x.kurt(numeric_only=True).round(3))
# Out:
# 🔹 Skewness:
# Unnamed: 0        0.000
# ID                0.000
# Age              -0.085
# Income in Rs.     0.052
# Score            10.577
# Purchases         0.297
# dtype: float64
#
# 🔹 Kurtosis:
# Unnamed: 0        -1.200
# ID                -1.200
# Age               -1.231
# Income in Rs.     -0.534
# Score            135.469
# Purchases         -0.351
# dtype: float64

# %% [markdown]
# #correlation

# %%
print("\n🔹 Correlation Matrix:")
print(x.corr(numeric_only=True).round(3))
# Out:
# 🔹 Correlation Matrix:
#                Unnamed: 0     ID    Age  Income in Rs.  Score  Purchases
# Unnamed: 0          1.000  1.000  0.028         -0.064 -0.063      0.051
# ID                  1.000  1.000  0.028         -0.064 -0.063      0.051
# Age                 0.028  0.028  1.000         -0.012  0.033      0.065
# Income in Rs.      -0.064 -0.064 -0.012          1.000  0.095      0.018
# Score              -0.063 -0.063  0.033          0.095  1.000      0.191
# Purchases           0.051  0.051  0.065          0.018  0.191      1.000

# %% [markdown]
# #visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")              #WHITE GRID STYLE
for col in x.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(x[col], kde=True, color='skyblue', bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #pair plot

# %%
selected = x.select_dtypes(include='number').columns[:4]  # First 4 numeric columns
sns.pairplot(x[selected], diag_kind='kde')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()
