# %% [markdown]
# #📊 Data Cleaning & Visualization Report:
# ##👩‍💻 Objective:
# The aim of this project is to clean, process, analyze, and visualize a numeric dataset containing columns such as Age, Income, Score, and Purchases. The final goal is to prepare this dataset for further statistical modeling and decision-making.
# To perform data cleaning on a numerical dataset by:
#
# Handling missing and negative values
#
# Treating outliers
#
# Correcting data types and labels
#
# Removing duplicates
#
# Visualizing distributions and relationship

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r'c:\Users\divya\Downloads\numeric_data_cleaning.csv')
x=df.copy()                                    ##copying the variable
x.head()
# Out:
#    ID  Age    Income  Score  Purchases
# 0   1   56  37972.58  75.24          4
# 1   2   46  70760.24  79.16          4
# 2   3   32  71078.08  78.96          5
# 3   4   25  70884.89   9.12          4
# 4   5   38  36790.39  49.44          1

# %% [markdown]
# 🧭 Data Overview

# %%
print("Shape:", x.shape)
print("Columns:", x.columns.tolist())
print(x.dtypes)
print(x.isnull().sum())
# Out:
# Shape: (200, 5)
# Columns: ['ID', 'Age', 'Income', 'Score', 'Purchases']
# ID             int64
# Age            int64
# Income       float64
# Score        float64
# Purchases      int64
# dtype: object
# ID           0
# Age          0
# Income       1
# Score        1
# Purchases    0
# dtype: int64

# %% [markdown]
# 🧹 Data Cleaning Summary
# ✅ Steps Taken:
# Filled missing values in 'Income' and 'Score' with their mean.
#
# Converted all values to positive using .abs() where logical.
#
# Replaced extreme outliers in 'Purchases' (values > 20).
#
# Renamed 'Income' to 'Income in Rs.'.
#
# Converted 'Score' and 'Income in Rs.' to int.
#
# Removed duplicate rows using drop_duplicates().

# %%
x.isnull().sum()
x['Income'].fillna(round(x['Income'].mean(), 2), inplace=True)
x['Score'].fillna(round(x['Score'].mean(), 2), inplace=True)
neg_indices = np.where(x < 0)
x.loc[100, 'Age'] = int(df['Age'].mean())
outlier_indices = np.where(x['Purchases'] > 20)
x['Score'] = x['Score'].astype(int)
x.rename(columns={'Income': 'Income in Rs.'})
x.duplicated().sum()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_28300\491492.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x['Income'].fillna(round(x['Income'].mean(), 2), inplace=True)
# C:\Users\divya\AppData\Local\Temp\ipykernel_28300\491492.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# 📊  Statistical Summary
# Summary statistics provided:
#
# Mean, Median, Std Dev, Min, Max, IQR for all numeric fields.
#
# Useful for identifying skewed distributions and validating cleaning steps.
#
# skeweness,kurtosis,correlation

# %%
x.describe().round(3)
print("Skewness:\n", x.skew(numeric_only=True).round(3))
print("\nKurtosis:\n", x.kurt(numeric_only=True).round(3))
plt.figure(figsize=(10, 8))
sns.heatmap(x.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Skewness:
#  ID            0.000
# Age          -0.085
# Income        0.052
# Score        10.577
# Purchases    14.122
# dtype: float64
#
# Kurtosis:
#  ID            -1.200
# Age           -1.231
# Income        -0.534
# Score        135.469
# Purchases    199.615
# dtype: float64

# %% [markdown]
# 📈  Visualizations
# 🧪 Histograms
# Distribution of numeric variables to detect skewness or gaps in data

# %%
for col in x.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(x[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #pair plot

# %%
sns.pairplot(x[x.columns[:4]], diag_kind='kde')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# ✅ Final Conclusion
# In this notebook, we successfully performed a complete data cleaning and exploratory analysis on the numeric_data_cleaning.csv dataset. The following key tasks were accomplished:
#
# 🧼 Data Cleaning: Missing values in 'Income' and 'Score' were filled using the mean. Negative values were addressed using absolute conversion where logical, and outliers in 'Purchases' were manually corrected.
#
# 🏷️ Data Type Correction: Variables such as 'Income' and 'Score' were converted to integer types. Column naming was standardized for clarity (e.g., 'Income' → 'Income in Rs.').
#
# 🔍 Duplicate Detection: Duplicate rows were identified and removed to ensure data integrity.
#
# 📊 Statistical Analysis: Descriptive statistics, skewness, and correlation metrics provided a solid understanding of feature distributions and relationships.
#
# 📈 Visualizations: Histograms, boxplots, and a correlation heatmap helped identify data patterns, skewness, outliers, and multicollinearity.
#
# 💾 Final Output: A fully cleaned dataset was saved as cleaned_file2.csv and is now ready for further modeling or analytical tasks.
#
# This cleaned and validated dataset forms a reliable foundation for advanced tasks such as:
#
# 📉 Predictive modeling
#
# 🧠 Machine learning
#
# 🧪 Hypothesis testing
#
# 🎯 Customer segmentation and analysis
