# %% [markdown]
# statistical analysis of clean data set

# %%
import pandas as pd

# Load cleaned data
df = pd.read_csv(r"C:\Users\divya\Desktop\data_cleaning\data_cleaning\cleaned_file.csv")

# %%
DESCRIPTIVE_STATS = df.describe().round(3)  # Descriptive statistics

# %%
print("🔹 Descriptive Statistics:")
print(df.describe().round(3))                        ##it tells about the data like mean, std, min, max, 25%, 50%, 75% etc.
# Out:
# 🔹 Descriptive Statistics:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count       1599.000          1599.000     1599.000        1599.000
# mean           8.320             0.528        0.271           2.548
# std            1.741             0.179        0.195           1.416
# min            4.600             0.120        0.000           0.900
# 25%            7.100             0.390        0.090           1.900
# 50%            7.900             0.520        0.260           2.200
# 75%            9.200             0.640        0.420           2.600
# max           15.900             1.580        1.000          15.500
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   1599.000             1599.000              1599.000  1599.000
# mean       0.088               15.875                46.468     0.997
# std        0.047               10.460                32.895     0.002
# ...

# %% [markdown]
# checking missing value for safty perpose

# %%
print("\n🔹 Missing Values:")
print(df.isnull().sum())
# Out:
# 🔹 Missing Values:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# SKEWNESS AND KURTOSIS

# %%
print("\n🔹 Skewness:")
print(df.skew(numeric_only=True).round(3))

print("\n🔹 Kurtosis:")
print(df.kurt(numeric_only=True).round(3))
# Out:
# 🔹 Skewness:
# fixed acidity           0.983
# volatile acidity        0.672
# citric acid             0.315
# residual sugar          4.481
# chlorides               5.682
# free sulfur dioxide     1.251
# total sulfur dioxide    1.516
# density                 0.071
# pH                     -4.573
# sulphates               2.429
# alcohol                 0.865
# quality                 0.218
# dtype: float64
#
# 🔹 Kurtosis:
# fixed acidity            1.132
# volatile acidity         1.226
# citric acid             -0.785
# residual sugar          27.992
# chlorides               41.740
# free sulfur dioxide      2.024
# total sulfur dioxide     3.810
# density                  0.934
# pH                      52.696
# sulphates               11.720
# alcohol                  0.238
# quality                  0.297
# dtype: float64

# %% [markdown]
# CORRELATION

# %%
print("\n🔹 Correlation Matrix:")
print(df.corr(numeric_only=True).round(3))
# Out:
# 🔹 Correlation Matrix:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                 1.000            -0.256        0.671
# volatile acidity             -0.256             1.000       -0.552
# citric acid                   0.671            -0.552        1.000
# residual sugar                0.113             0.000        0.142
# chlorides                     0.094             0.060        0.204
# free sulfur dioxide          -0.154            -0.011       -0.061
# total sulfur dioxide         -0.113             0.076        0.034
# density                       0.668             0.022        0.364
# pH                           -0.501             0.191       -0.408
# sulphates                     0.183            -0.261        0.312
# alcohol                      -0.056            -0.203        0.112
# quality                       0.124            -0.391        0.226
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")              #WHITE GRID STYLE
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, color='skyblue', bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
selected = df.select_dtypes(include='number').columns[:4]  # First 4 numeric columns
sns.pairplot(df[selected], diag_kind='kde')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()
